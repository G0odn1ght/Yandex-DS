# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Подготовка-данных" data-toc-modified-id="1.-Подготовка-данных-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>1. Подготовка данных</a></span></li><li><span><a href="#1.1.-Откроем-файлы-и-изучим-их." data-toc-modified-id="1.1.-Откроем-файлы-и-изучим-их.-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>1.1. Откроем файлы и изучим их.</a></span></li><li><span><a href="#1.2.-Проверим,-что-эффективность-обогащения-рассчитана-правильно.-Рассчитаем-MAE" data-toc-modified-id="1.2.-Проверим,-что-эффективность-обогащения-рассчитана-правильно.-Рассчитаем-MAE-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>1.2. Проверим, что эффективность обогащения рассчитана правильно. Рассчитаем MAE</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Наименование-признаков" data-toc-modified-id="Наименование-признаков-0.5"><span class="toc-item-num">0.5&nbsp;&nbsp;</span>Наименование признаков</a></span></li><li><span><a href="#1.4.-Предобработка-данных." data-toc-modified-id="1.4.-Предобработка-данных.-0.6"><span class="toc-item-num">0.6&nbsp;&nbsp;</span>1.4. Предобработка данных.</a></span></li><li><span><a href="#Выводы-по-Разделу-1" data-toc-modified-id="Выводы-по-Разделу-1-0.7"><span class="toc-item-num">0.7&nbsp;&nbsp;</span>Выводы по Разделу 1</a></span></li></ul></li><li><span><a href="#2.-Анализ-данных" data-toc-modified-id="2.-Анализ-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>2. Анализ данных</a></span><ul class="toc-item"><li><span><a href="#2.1.-Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки." data-toc-modified-id="2.1.-Посмотрим,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>2.1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.</a></span></li><li><span><a href="#2.2.-Сравним-распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="2.2.-Сравним-распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>2.2. Сравним распределение размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#2.3.-Посмотрим-на-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="2.3.-Посмотрим-на-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>2.3. Посмотрим на суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li><li><span><a href="#Выводы-по-разделу-2" data-toc-modified-id="Выводы-по-разделу-2-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Выводы по разделу 2</a></span></li></ul></li><li><span><a href="#3.-Модель" data-toc-modified-id="3.-Модель-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>3. Модель</a></span><ul class="toc-item"><li><span><a href="#3.1.-Напишем-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="3.1.-Напишем-функцию-для-вычисления-итоговой-sMAPE.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>3.1. Напишем функцию для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#3.2.-Обучим-разные-модели-и-оценим-их-качество-кросс-валидацией.-Выберем-лучшую-модель-и-проверим-её-на-тестовой-выборке." data-toc-modified-id="3.2.-Обучим-разные-модели-и-оценим-их-качество-кросс-валидацией.-Выберем-лучшую-модель-и-проверим-её-на-тестовой-выборке.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>3.2. Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке.</a></span></li><li><span><a href="#Итоговые-выводы-по-проекту" data-toc-modified-id="Итоговые-выводы-по-проекту-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Итоговые выводы по проекту</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Необходмо подготовить прототип модели машинного обучения для предприятия «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
#
# Нам доступны данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# План работ по проекту:
#
# 1. Подготовка данных
#     * 1.1. Откроем файлы и изучим их.
#     * 1.2. Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между полученными расчётами и значением признака.
#     * 1.3. Проанализируем признаки, недоступные в тестовой выборке.
#     * 1.4. Проведем предобработку данных.
# 2. Анализ данных
#     * 2.1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.
#     * 2.2. Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.
#     * 2.3. Посмотрим на суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# 3. Построим модель
#     * 3.1. Напишем функцию для вычисления итоговой sMAPE.
#     * 3.2. Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке.

# %% [markdown]
# ### 1. Подготовка данных

# %%
import pandas as pd
import numpy as np
import re
from scipy import stats as st
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from numpy.random import RandomState
from scipy import stats
import copy

from sklearn.inspection import permutation_importance
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn import linear_model
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_error, make_scorer
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, StratifiedKFold, GridSearchCV, cross_validate, KFold
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
#установим лимит отображения строк и колонок
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### 1.1. Откроем файлы и изучим их. ###

# %%
try:
    train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
    test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
    full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
except:
    train = pd.read_csv('gold_recovery_train_new.csv')
    test = pd.read_csv('gold_recovery_test_new.csv')
    full = pd.read_csv('gold_recovery_full_new.csv')
train.name = "Обучающая выборка"
test.name = "Тестовая выборка"
full.name = "Полная выборка"

# %%
for data in [train, test, full]:
    print(f'{data.name}:', data.shape)
# Out:
# Обучающая выборка: (14149, 87)
# Тестовая выборка: (5290, 53)
# Полная выборка: (19439, 87)

# %%
for data in [train, test, full]:
    print(f'{data.name}:', data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
for data in [train, test, full]:
    print(f'{data.name}:')
    display(data.head())
# Out:
# Обучающая выборка:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
for data in [train, test, full]:
    print(f'Количество пропусков в {data.name}:', sum(data.isnull().sum()))
# Out:
# Количество пропусков в Обучающая выборка: 4100
# Количество пропусков в Тестовая выборка: 90
# Количество пропусков в Полная выборка: 4481

# %%
for data in [train, test, full]:
    print(f'Количество дубликатов в {data.name}:', sum(data.duplicated()))
# Out:
# Количество дубликатов в Обучающая выборка: 0
# Количество дубликатов в Тестовая выборка: 0
# Количество дубликатов в Полная выборка: 0

# %%
# построим гистограммы и оценим распределение и наличие выбросов
for data in [train, test, full]:
    data.hist(figsize=(35, 35))
    print(f'{data.name}:')
# Out:
# Обучающая выборка:
# Тестовая выборка:
# Полная выборка:

# %% [markdown]
# ### 1.2. Проверим, что эффективность обогащения рассчитана правильно. Рассчитаем MAE ###

# %% [markdown]
# ![](Recovery_1576238822.jpg)

# %%
def MAE_check(data):
    data_slice = data[~data['rougher.output.recovery'].isnull()]
    C = data_slice['rougher.output.concentrate_au']
    F = data_slice['rougher.input.feed_au']
    T = data_slice['rougher.output.tail_au']
    data_slice['recovery_calculated'] = (C * (F - T)) / (F * (C - T)) * 100
    MAE = mean_absolute_error(data_slice['recovery_calculated'], data_slice['rougher.output.recovery'])
    return MAE

# %%
print(f"MAE: {MAE_check(train)}")
# Out:
# MAE: 9.73512347450521e-15

# %% [markdown]
# Величина ***MAE крайне мала***, это указывет на то, что параметр ***Recovery (эффективность обогащения) посчитан верно***.

# %%
#выведем отсутствующие в тестовой выборке признаки
columns_to_drop = [col for col in list(train.columns) if (col not in list(test.columns))]
columns_to_drop
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
# ...

# %%
print('Количество отличных признаков:', len(set(train.columns) - set(test.columns)))
# Out:
# Количество отличных признаков: 34

# %% [markdown]
# ### Описание данных
# * Технологический процесс
#     - Rougher feed — исходное сырье
#     - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#     - Xanthate **— ксантогенат (промотер, или активатор флотации);
#     - Sulphate — сульфат (на данном производстве сульфид натрия);
#     - Depressant — депрессант (силикат натрия).
#     - Rougher process (англ. «грубый процесс») — флотация
#     - Rougher tails — отвальные хвосты
#     - Float banks — флотационная установка
#     - Cleaner process — очистка
#     - Rougher Au — черновой концентрат золота
#     - Final Au — финальный концентрат золота
# * Параметры этапов
#     - air amount — объём воздуха
#     - fluid levels — уровень жидкости
#     - feed size — размер гранул сырья
#     - feed rate — скорость подачи
#
#
# ### Наименование признаков
#
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
# Пример: rougher.input.feed_ag
# * Возможные значения для блока [этап]:
#     - rougher — флотация
#     - primary_cleaner — первичная очистка
#     - secondary_cleaner — вторичная очистка
#     - final — финальные характеристики
# * Возможные значения для блока [тип_параметра]:
#     - input — параметры сырья
#     - output — параметры продукта
#     - state — параметры, характеризующие текущее состояние этапа
#     - calculation — расчётные характеристики

# %% [markdown]
# ***Всего в тестовой выборке отсутствуют 34 столбца.***
#
# В тестовой выборке отсутствуют признаки final.output, primary_cleaner.output, rougher.output, secondary_cleaner.output.
# Данные относятся к параметрам продукта, параметрам характеризующим текущее состояние этапа и расчетные характеристики.

# %% [markdown]
# ### 1.4. Предобработка данных. ###

# %%
# проанализируем пропуски
for data in [train, test, full]:
    print(f'Количество пропусков {data.name}:', sum(data.isnull().sum()))
# Out:
# Количество пропусков Обучающая выборка: 4100
# Количество пропусков Тестовая выборка: 90
# Количество пропусков Полная выборка: 4481

# %%
# заполним пропуски на основании данных предыдущих по времени forward fill
train = train.fillna(method = 'ffill')
train.name = "Обучающая выборка"

test = test.fillna(method = 'ffill')
test.name = "Тестовая выборка"

full = full.fillna(method = 'ffill')
full.name = "Полная выборка"

# %%
# проверим 
for data in [train, test, full]:
    print(f'Количество пропусков {data.name}:', sum(data.isnull().sum()))
# Out:
# Количество пропусков Обучающая выборка: 0
# Количество пропусков Тестовая выборка: 0
# Количество пропусков Полная выборка: 0

# %% [markdown]
# ### Выводы по Разделу 1 ###
#
# * Мы загрузили данные и проанализировали общую информацию об их содержании.
#
# * Гистограммы данных не вызывают особого подозрения, в основном данные распределены нормально. Было принято решение не обрабатывать данные методом трех сигм так как из-за значительного количества признаков (86) большое количество записей могло попасть под удаление.
#
# * В Тестовой выборке отсутствуют 34 Признака доступные в Полной и Обучающей выборках.
#
# * Также мы обнаружили и заполнили методом forward fill пропущенные значения, так как данные в датасетах содержат Timestamp.
#
# * Рассчитав MAE мы убедились, что эффективность обогащения рассчитана правильно (recovery)

# %% [markdown]
# ## 2. Анализ данных

# %% [markdown]
# ### 2.1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. ###

# %% [markdown]
# ***Построим графики по концентрации Золота***

# %%
plt.figure(figsize=[15,8])

plt.hist(train['final.output.concentrate_au'], bins=150, label = 'final.output', alpha=.5)
plt.hist(train['primary_cleaner.output.concentrate_au'], bins=150, label = 'primary_cleaner.output', alpha=.5)
plt.hist(train['rougher.output.concentrate_au'], bins=150, label = 'rougher.output', alpha=.5)
plt.hist(train['rougher.input.feed_au'], bins=150, label = 'rougher.input.feed', alpha=.5)

plt.xlim([0, 55])
plt.ylim([0, 1100])

plt.xlabel("Концентрация золота по этапам")
plt.ylabel("Кол-во наблюдений")
plt.legend(loc='upper left', fontsize='x-large')

plt.title("Концентрации золота на этапах очистки")
plt.show()

# %% [markdown]
# Концентрация золота возрастает по мере выполнения технологического процесса, что и является его целью.

# %% [markdown]
# ***Построим графики по концентрации Серебра***

# %%
plt.figure(figsize=[15,8])

plt.hist(train['final.output.concentrate_ag'], bins=100, label = 'final.output', alpha=.5)
plt.hist(train['primary_cleaner.output.concentrate_ag'], bins=100, label = 'primary_cleaner.output', alpha=.5)
plt.hist(train['rougher.output.concentrate_ag'], bins=100, label = 'rougher.output', alpha=.5)
plt.hist(train['rougher.input.feed_ag'], bins=100, label = 'rougher.input.feed', alpha=.5)

plt.xlim([0, 20])
plt.ylim([0, 850])

plt.xlabel("Концентрация серебра по этапам")
plt.ylabel("Кол-во наблюдений")

plt.legend(loc='upper right', fontsize='x-large')

plt.title("Концентрации серебра на этапах очистки")
plt.show()

# %% [markdown]
# Концентрация серебра в процессе очистки уменьшается, вероятнее всего ввиду того, что технологический процесс изначально нацелен на обогащение золота, часть серебра остается в отвале.

# %% [markdown]
# ***Построим графики по концентрации Свинца***

# %%
plt.figure(figsize=[15,8])

plt.hist(train['final.output.concentrate_pb'], bins=100, label = 'final.output', alpha=.5)
plt.hist(train['primary_cleaner.output.concentrate_pb'], bins=100, label = 'primary_cleaner.output', alpha=.5)
plt.hist(train['rougher.output.concentrate_pb'], bins=100, label = 'rougher.output', alpha=.5)
plt.hist(train['rougher.input.feed_pb'], bins=100, label = 'rougher.input.feed', alpha=.5)

plt.xlim([0, 20])
plt.ylim([0, 750])

plt.xlabel("Концентрация свинца по этапам")
plt.ylabel("Кол-во наблюдений")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Концентрации свинца на этапах очистки")
plt.show()

# %% [markdown]
# Концентрация свинца в процессе обработки увеличивается после первого этапа обработки.

# %% [markdown]
# Можем наблюдать выбросы в виде околонулевых значений на всех графиках, удалим их.

# %%
zeros_to_drop = [
                'final.output.concentrate_au',
                'primary_cleaner.output.concentrate_au',
                'rougher.output.concentrate_au',
                'rougher.input.feed_au',

                'final.output.concentrate_ag',
                'primary_cleaner.output.concentrate_ag',
                'rougher.output.concentrate_ag',
                'rougher.input.feed_ag',

                'final.output.concentrate_pb',
                'primary_cleaner.output.concentrate_pb',
                'rougher.output.concentrate_pb',
                'rougher.input.feed_pb'
                ]

train = train[train[zeros_to_drop].min(axis=1) > 0.1]
train.name = "Обучающая выборка"

# %% [markdown]
# Далее на сводном графике проверим результат удаления. Чтобы не дублировать вывод всех графиков.

# %% [markdown]
# ### 2.2. Сравним распределение размеров гранул сырья на обучающей и тестовой выборках. ###

# %%
plt.figure(figsize=[15,8])

plt.hist(train['rougher.input.feed_size'], bins=200, label = 'Train rougher.input.feed_size', alpha=.5)
plt.hist(test['rougher.input.feed_size'], bins=200, label = 'Test rougher.input.feed_size', alpha=.5)

plt.xlim([0, 550])
plt.ylim([0, 1500])

plt.xlabel("Размер гранул сырья")
plt.ylabel("Кол-во наблюдений")

plt.legend(loc='upper right', fontsize='x-large')

plt.title("Распределение размеров гранул сырья на обучающей и тестовой выборках перед флотацией")
plt.show()

# %%
plt.figure(figsize=[15,8])

plt.hist(train['primary_cleaner.input.feed_size'], bins=100, label = 'Train primary_cleaner.input.feed_size', alpha=.5)
plt.hist(test['primary_cleaner.input.feed_size'], bins=100, label = 'Test primary_cleaner.input.feed_size', alpha=.5)

plt.xlim([0, 16])
plt.ylim([0, 1300])

plt.xlabel("Размер гранул сырья")
plt.ylabel("Кол-во наблюдений")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Распределение размеров гранул сырья на обучающей и тестовой выборках перед первичной очисткой")
plt.show()

# %% [markdown]
# Размеры гранул сырья на обучающей и тестовой выборках повторяют друг друга, это говорит о том, что дальнейшая оценка модели будет адекватной.

# %% [markdown]
# ### 2.3. Посмотрим на суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах. ###

# %%
# Сумма концентраций всех веществ в сырье.
raw_concentrate = (train['rougher.input.feed_ag'] + 
                   train['rougher.input.feed_pb'] + 
                   train['rougher.input.feed_sol'] + 
                   train['rougher.input.feed_au'])

# Сумма всех веществ в черновом концентрате.
rougher_concentrate = (train['rougher.output.concentrate_ag'] + 
                       train['rougher.output.concentrate_pb'] +  
                       train['rougher.output.concentrate_sol'] + 
                       train['rougher.output.concentrate_au'])

# Суммарный отвал всех веществ в черновом конценрате.
rougher_tail= (train['rougher.output.tail_ag'] + 
               train['rougher.output.tail_pb'] +
               train['rougher.output.tail_sol'] + 
               train['rougher.output.tail_au'])

# Сумма всех веществ в финальном концентрате.
final_concentrate = (train['final.output.concentrate_ag'] + 
                     train['final.output.concentrate_pb'] + 
                     train['final.output.concentrate_sol'] + 
                     train[ 'final.output.concentrate_au'])

# Суммарный отвал всех веществ в финальном концентрате.
final_tail = (train['final.output.tail_ag'] + 
              train['final.output.tail_pb'] +
              train['final.output.tail_sol'] + 
              train['final.output.tail_au'])

# %%
plt.figure(figsize=[15,8])

plt.hist(raw_concentrate, bins=100, label = 'rougher.input', alpha=.5)
plt.hist(rougher_concentrate, bins=100, label = 'rougher.output.concentrate', alpha=.5)
plt.hist(rougher_tail, bins=100, label = 'rougher.output.tail', alpha=.5)
plt.hist(final_concentrate, bins=100, label = 'final.output.concentrate', alpha=.5)
plt.hist(final_tail, bins=100, label = 'final.output.tail', alpha=.5)

plt.xlim([0, 100])
plt.ylim([0, 2000])

plt.xlabel("суммарная концентрация по этапам")
plt.ylabel("Кол-во наблюдений")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Суммарная конценрация веществ по этапам")
plt.show()

# %% [markdown]
# ### Выводы по разделу 2
#
# Мы построили графики концентрации золота, серебра и свинца по этапам.
# Концентрация золота по мере выполнения технологического процесса увеличивается, что и является целью процесса.
#
# Размеры гранул сырья на Обучающей и Тестовой выборках соответствуют друг другу, что делает возможным дальнейшее построение модели.

# %% [markdown]
# ## 3. Модель

# %% [markdown]
# ### 3.1. Напишем функцию для вычисления итоговой sMAPE. ###

# %% [markdown]
# ![](smape_1576239058.jpg)

# %%
def smape(y_target, y_pred):
    return ((1/len(y_target)) * np.sum(2 * np.abs(y_target - y_pred) / (np.abs(y_target) + np.abs(y_pred)))) * 100

# %% [markdown]
# ### 3.2. Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке. ###

# %% [markdown]
# Модели:
# * Lasso
# * RandomForest
# * LinearRegression
#
# Используем Gridsearch.
#
# Выберем оптимальную модель и протестим ее на тестовой выборке.
#
# Посчитаем sMAPE

# %%
# удалим признаки отсутствующие в Test из Train
train = train.drop(columns_to_drop, axis = 1)
train.name = "Обучающая выборка"
# check
print(f'{train.name}:', train.shape)
print(f'{test.name}:', test.shape)
# Out:
# Обучающая выборка: (13591, 53)
# Тестовая выборка: (5290, 53)

# %%
# Сделаем столбец с Timestamp индексом для удобства мэтчинга таблиц и заодно удалим его чтобы не мешался при построении моделей
full.set_index('date', drop=True, inplace=True)
test.set_index('date', drop=True, inplace=True)
train.set_index('date', drop=True, inplace=True)

X_train_rougher = copy.copy(train)
X_test_rougher = copy.copy(test)
y_train_rougher = full.loc[X_train_rougher.index, 'rougher.output.recovery']
y_test_rougher = full.loc[X_test_rougher.index,'final.output.recovery']

X_train_final = copy.copy(train)
X_test_final = copy.copy(test)
y_train_final = full.loc[X_train_final.index, 'final.output.recovery']
y_test_final = full.loc[X_test_final.index, 'final.output.recovery']

# %%
print(X_train_rougher.shape, X_train_final.shape)
print(X_test_rougher.shape, X_test_final.shape)
print(y_train_rougher.shape, y_train_final.shape)
print(y_test_rougher.shape, y_test_final.shape)
# Out:
# (13591, 52) (13591, 52)
# (5290, 52) (5290, 52)
# (13591,) (13591,)
# (5290,) (5290,)

# %%
# настроим Пайплайн

state = RandomState(12345)

pipe = Pipeline([
        ('imp', SimpleImputer(missing_values=np.nan)),
        ('scaler', StandardScaler()),
        ('model', "Подберем оптимальную модель")
])

params = [
    {
        'imp__strategy': ['mean', 'median'],
        'model': [RandomForestRegressor(random_state=state)],
        'model__n_estimators': [20, 30],
        'model__max_features': np.linspace(0.1, 1, 10)
    }, {
        'imp__strategy': ['mean', 'median'],
        'model': [LinearRegression()]
    }, {
        'imp__strategy': ['mean', 'median'],
        'model': [linear_model.Lasso(random_state=state)],
        'model__alpha': np.logspace(-3, 1, 10)
    }
]

# %%
#sMAPE для GridSearchCV
smape_score = make_scorer(smape, greater_is_better=False)

# %%
# Проведем кросс валидацию с помощью kFold и разделим на 5 частей
cv = KFold(n_splits=5, shuffle=False)
grid_rougher = GridSearchCV(pipe, param_grid=params, cv=cv, n_jobs=-1, scoring=smape_score)

# %%
grid_rougher.fit(X_train_rougher, y_train_rougher)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('imp', SimpleImputer()),
#                                        ('scaler', StandardScaler()),
#                                        ('model',
#                                         RandomForestRegressor(random_state=RandomState(MT19937) at 0x16B32AA40))]),
#              n_jobs=-1,
#              param_grid=[{'imp__strategy': ['mean', 'median'],
#                           'model': [RandomForestRegressor(max_features=0.7000000000000001,
#                                                           n_es...
#                           'model': [LinearRegression()]},
#                          {'imp__strategy': ['mean', 'median'],
#                           'model': [Lasso(random_state=RandomState(MT19937) at 0x16B32AA40)],
#                           'model__alpha': array([1.00000000e-03, 2.78255940e-03, 7.74263683e-03, 2.15443469e-02,
# ...

# %%
#Выведем наилучшие подобранные параметры для rougher
print('Лучшие параметры GridSearch:', grid_rougher.best_params_)
print('Лучший sMAPE:', -grid_rougher.best_score_)
# Out:
# Лучшие параметры GridSearch: {'imp__strategy': 'mean', 'model': RandomForestRegressor(max_features=0.7000000000000001, n_estimators=20,
#                       random_state=RandomState(MT19937) at 0x16B32AA40), 'model__max_features': 0.7000000000000001, 'model__n_estimators': 20}
# Лучший sMAPE: 6.410079315106799

# %%
# Поиск лучших параметров для final 
grid_final = GridSearchCV(pipe, param_grid=params, cv=cv, n_jobs=-1,scoring=smape_score)

# %%
grid_final.fit(X_train_final, y_train_final)
# Out:
# /Users/andrew/Documents/Python_projects/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.996e+03, tolerance: 9.635e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/andrew/Documents/Python_projects/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.221e+02, tolerance: 9.635e+01
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
#Выведем наилучшие подобранные параметры для rougher final
print('Лучшие параметры GridSearch:', grid_final.best_params_)
print('Лучший sMAPE::', -grid_final.best_score_)
# Out:
# Лучшие параметры GridSearch: {'imp__strategy': 'mean', 'model': Lasso(alpha=0.46415888336127775,
#       random_state=RandomState(MT19937) at 0x16B32AA40), 'model__alpha': 0.46415888336127775}
# Лучший sMAPE:: 9.196116524023939

# %%
#Модель с лучшими параметрами для Тестовой выборки Rougher
pipe_rougher = grid_rougher.best_estimator_

# pipe_rougher.fit(X_train_rougher, y_train_rougher)
y_pred = grid_rougher.predict(X_test_rougher)

smape_rougher = smape(full.loc[X_test_rougher.index, 'rougher.output.recovery'], y_pred)
smape_rougher
# Out:
# 8.152906302270734

# %%
#Модель с лучшими параметрами для Тестовой выборки Final
pipe_final = grid_final.best_estimator_
    
pipe_final.fit(X_train_final, y_train_final)
y_pred_final = pipe_final.predict(X_test_final)

smape_final = smape(full.loc[X_test_rougher.index, 'final.output.recovery'],y_pred_final)
smape_final
# Out:
# 8.851828725728714

# %% [markdown]
# ![](_smape_1576239054.jpg)

# %%
#Итоговый sMAPE
final_smape = 0.25*smape_rougher + 0.75*smape_final
final_smape
# Out:
# 8.677098119864219

# %%
# проверим модель на адекватность
rougher_median = pd.Series(y_train_rougher.median(), index=y_test_rougher.index)
final_median = pd.Series(y_train_final.median(), index=y_test_final.index)

total = (smape(y_test_final, rougher_median)*0.25) + (smape(y_test_rougher, final_median)* 0.75)
print("sMAPE модели для проверик:", total)
if final_smape < total:
    print("Модель прошла проверку на адекватность!")
else:
    print("Модель НЕ прошла проверку на адекватность.")
# Out:
# sMAPE модели для проверик: 13.190643005932252
# Модель прошла проверку на адекватность!

# %% [markdown]
# ### Итоговые выводы по проекту
#
# Для исследования нам было предосталено 3 датасета:
# * gold_recovery_train_new.csv - Обучающая выборка
# * gold_recovery_test_new.csv - Тестовая выборка
# * gold_recovery_full_new.csv - Исходная / Полная выборка
#
# Методомо Forward Fill мы заполнили пропуски в данных.
# Мы рассчитали целевой признак - эффективность обогащения по формуле для Обучающей выборки и рассчитали МАЕ между рассчетным и целевым признаком, величина МАЕ подтвердила что целевой признак в Обучающей выборке рассчитан корректно.
#
# На основании графиков мы определили, что концентрация золота по мере выполнения технологического процесса увеличивается, что и является целью процесса.
#
# Также мы проверили, что размеры гранул сырья на Обучающей и Тестовой выборках соответствуют друг другу, что делает возможным дальнейшее построение модели.
#
# Мы обучили и построили три модели:
# * Lasso
# * RandomForest
# * LinearRegression
#
# Применили **метод GridsearchCV** для определения наилучшей модели и подбора наилучщих гиперпараметров.
#
# Рассчитали **sMAPE**:
# * **rougher.output.recovery** - модель RandomForestRegressor - sMAPE = **6.4**
# * **final.output.recovery** - модель Lasso - sMAPE = **9.2**
#
# **Итоговый sMAPE по формуле 25/75 = 8.7%**
